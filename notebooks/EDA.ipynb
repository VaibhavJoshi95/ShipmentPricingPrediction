# %%
import pandas as pd

# %%
data=pd.read_csv('data/SCMS_Datasets.csv')

# %%
data.head()
# Out:
#         Country Shipment_Mode  Qauntity_of_pack  Pack_Price  Weight_Kg  \
# 0        Rwanda           Air               100        0.01         99
# 1       Vietnam           Air                60        7.00        148
# 2       Vietnam           Air                30       23.26         55
# 3  Cote dIvoire         Truck                30       13.52          7
# 4       Burundi           Air                60        6.52        186
#
#    Freight_Cost_USD  Product_Insurance_USD
# 0              0.75                   0.02
# 1             14.36                   5.49
# 2             17.72                  10.73
# 3             22.29                   0.99
# 4             29.21                   6.37

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2598 entries, 0 to 2597
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                2598 non-null   object
#  1   Shipment_Mode          2598 non-null   object
#  2   Qauntity_of_pack       2598 non-null   int64
#  3   Pack_Price             2598 non-null   float64
#  4   Weight_Kg              2598 non-null   int64
#  5   Freight_Cost_USD       2598 non-null   float64
#  6   Product_Insurance_USD  2598 non-null   float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 142.2+ KB

# %%
data.head()
# Out:
#         Country Shipment_Mode  Qauntity_of_pack  Pack_Price  Weight_Kg  \
# 0        Rwanda           Air               100        0.01         99
# 1       Vietnam           Air                60        7.00        148
# 2       Vietnam           Air                30       23.26         55
# 3  Cote dIvoire         Truck                30       13.52          7
# 4       Burundi           Air                60        6.52        186
#
#    Freight_Cost_USD  Product_Insurance_USD
# 0              0.75                   0.02
# 1             14.36                   5.49
# 2             17.72                  10.73
# 3             22.29                   0.99
# 4             29.21                   6.37

# %%
import seaborn as sns

# %%
##Segregate numerical and Categorical columns

numerical_columns=data.columns[data.dtypes!='object']
categorical_columns=data.columns[data.dtypes=='object']

# %%
print('numerical_columns:',numerical_columns)
print('categorical_columns',categorical_columns)
# Out:
# numerical_columns: Index(['Qauntity_of_pack', 'Pack_Price', 'Weight_Kg', 'Freight_Cost_USD',
#        'Product_Insurance_USD'],
#       dtype='object')
# categorical_columns Index(['Country', 'Shipment_Mode'], dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,10))

# %%
sns.heatmap(data.corr(numeric_only=True),annot = True)
# Out:
# <Axes: >

# %%
sns.pairplot(data)

# %%
data['Country'].unique()
# Out:
# array(['Rwanda', 'Vietnam', 'Cote dIvoire', 'Burundi', 'Mozambique',
#        'Uganda', 'Zambia', 'Namibia', 'Congo, DRC', 'Kenya', 'Zimbabwe',
#        'Ethiopia', 'Guyana', 'Nigeria', 'Sudan', 'South Africa',
#        'Guatemala', 'Ghana', 'Haiti', 'Botswana', 'Pakistan',
#        'Dominican Republic', 'Liberia', 'Swaziland', 'Afghanistan',
#        'Cameroon', 'Malawi', 'Lesotho', 'Senegal', 'Tanzania',
#        'South Sudan', 'Libya', 'Mali', 'Angola', 'Benin', 'Guinea',
#        'Togo'], dtype=object)

# %%
country_map={'Rwanda':1, 'Vietnam':2, "Cote dIvoire":3, 'Burundi':4, 'Mozambique':5,
       'Uganda':6, 'Zambia':7, 'Namibia':8, 'Congo, DRC':9, 'Kenya':10, 'Zimbabwe':11,
       'Ethiopia':12, 'Guyana':13, 'Nigeria':14, 'Sudan':15, 'South Africa':16,
       'Guatemala':17, 'Ghana':18, 'Haiti':19, 'Botswana':20, 'Pakistan':21,
       'Dominican Republic':22, 'Liberia':23, 'Swaziland':24, 'Afghanistan':25,
       'Cameroon':26, 'Malawi':27, 'Lesotho':28, 'Senegal':29, 'Tanzania':30,
       'South Sudan':31, 'Libya':32, 'Mali':33, 'Angola':34, 'Benin':35, 'Guinea':36,
       'Togo':37}

# %%
data['Shipment_Mode'].unique()
# Out:
# array(['Air', 'Truck', 'Air Charter', 'Ocean'], dtype=object)

# %%
Shipment_Mode_map={'Air':1, 'Truck':2, 'Air Charter':3, 'Ocean':4}

# %%
data['Country'].map(country_map)
# Out:
# 0        1
# 1        2
# 2        2
# 3        3
# 4        4
#         ..
# 2593    11
# 2594     3
# 2595    24
# 2596    10
# 2597    31
# Name: Country, Length: 2598, dtype: int64

# %%
data['Shipment_Mode'].map(Shipment_Mode_map)
# Out:
# 0       1
# 1       1
# 2       1
# 3       2
# 4       1
#        ..
# 2593    2
# 2594    1
# 2595    2
# 2596    1
# 2597    1
# Name: Shipment_Mode, Length: 2598, dtype: int64
