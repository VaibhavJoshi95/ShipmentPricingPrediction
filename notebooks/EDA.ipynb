# %%
import pandas as pd

# %%
data=pd.read_csv('data/SCMS_Datasets.csv')

# %%
data.head()
# Out:
#    Unnamed: 0       Country Shipment Mode  Qauntity_of_pack  Pack Price  \
# 0           0        Rwanda           Air               100        0.01
# 1           1       Vietnam           Air                60        7.00
# 2           2       Vietnam           Air                30       23.26
# 3           3  Côte dIvoire         Truck                30       13.52
# 4           4       Burundi           Air                60        6.52
#
#    Weight (Kilograms)  Freight_Cost_USD  Product_Insurance_USD
# 0                  99              0.75                   0.02
# 1                 148             14.36                   5.49
# 2                  55             17.72                  10.73
# 3                   7             22.29                   0.99
# 4                 186             29.21                   6.37

# %%
data.rename(columns={'Freight Cost (USD)':'Freight_Cost_USD',
                     'Unit of Measure (Per Pack)':'Qauntity_of_pack',
                     'Line Item Insurance (USD)':"Product_Insurance_USD",
                     'Weight (Kilograms)':'Weight_(Kilograms)',
                     'Pack Price':'Pack_Price',
                     'Shipment Mode':'Shipment_Mode'},inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5856 entries, 0 to 5855
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             5856 non-null   int64
#  1   Country                5856 non-null   object
#  2   Shipment_Mode          5856 non-null   object
#  3   Qauntity_of_pack       5856 non-null   int64
#  4   Pack_Price             5856 non-null   float64
#  5   Weight_(Kilograms)     5856 non-null   int64
#  6   Freight_Cost_USD       5856 non-null   float64
#  7   Product_Insurance_USD  5856 non-null   float64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 366.1+ KB

# %%
data.drop(columns='Unnamed: 0',inplace=True,axis=1)

# %%
data.head()
# Out:
#         Country Shipment_Mode  Qauntity_of_pack  Pack_Price  \
# 0        Rwanda           Air               100        0.01
# 1       Vietnam           Air                60        7.00
# 2       Vietnam           Air                30       23.26
# 3  Côte dIvoire         Truck                30       13.52
# 4       Burundi           Air                60        6.52
#
#    Weight_(Kilograms)  Freight_Cost_USD  Product_Insurance_USD
# 0                  99              0.75                   0.02
# 1                 148             14.36                   5.49
# 2                  55             17.72                  10.73
# 3                   7             22.29                   0.99
# 4                 186             29.21                   6.37

# %%
data.to_csv('data/SCMS_Datasets.csv')

# %%
def costing(cost):
    cost=str(cost)
    if "," in cost:
        cost=cost.replace(",","")
        return float(cost)
    else:
        return float(cost) 
        
data["Freight_Cost_USD"] = data["Freight_Cost_USD"].apply(costing)
data["Freight_Cost_USD"].head(5)
# Out:
# 0     0.75
# 1    14.36
# 2    17.72
# 3    22.29
# 4    29.21
# Name: Freight_Cost_USD, dtype: float64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6197 entries, 0 to 6196
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Project Code            6197 non-null   object
#  1   Country                 6197 non-null   object
#  2   Vendor INCO Term        6197 non-null   object
#  3   Shipment Mode           5986 non-null   object
#  4   Delivery Recorded Date  6197 non-null   object
#  5   Qauntity_of_pack        6197 non-null   int64
#  6   Pack Price              6197 non-null   float64
#  7   Weight (Kilograms)      6175 non-null   float64
#  8   Freight_Cost_USD        6197 non-null   float64
#  9   Product_Insurance_USD   6006 non-null   float64
# dtypes: float64(4), int64(1), object(5)
# memory usage: 484.3+ KB

# %%
def costing(wt):
    wt=str(wt)
    if "," in wt:
        cost=cost.replace(",","")
        return float(wt)
    else:
        return float(wt) 
        
data["Weight (Kilograms)"] = data["Weight (Kilograms)"].apply(costing)
data["Weight (Kilograms)"].head(5)
# Out:
# 0     99.0
# 1    148.0
# 2     55.0
# 3      7.0
# 4    186.0
# Name: Weight (Kilograms), dtype: float64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6197 entries, 0 to 6196
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Project Code            6197 non-null   object
#  1   Country                 6197 non-null   object
#  2   Vendor INCO Term        6197 non-null   object
#  3   Shipment Mode           5986 non-null   object
#  4   Delivery Recorded Date  6197 non-null   object
#  5   Qauntity_of_pack        6197 non-null   int64
#  6   Pack Price              6197 non-null   float64
#  7   Weight (Kilograms)      6175 non-null   float64
#  8   Freight_Cost_USD        6197 non-null   float64
#  9   Product_Insurance_USD   6006 non-null   float64
# dtypes: float64(4), int64(1), object(5)
# memory usage: 484.3+ KB

# %%
data.isna().sum()
# Out:
# Project Code                0
# Country                     0
# Vendor INCO Term            0
# Shipment Mode             211
# Delivery Recorded Date      0
# Qauntity_of_pack            0
# Pack Price                  0
# Weight (Kilograms)         22
# Freight_Cost_USD            0
# Product_Insurance_USD     191
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isna().sum()
# Out:
# Project Code              0
# Country                   0
# Vendor INCO Term          0
# Shipment Mode             0
# Delivery Recorded Date    0
# Qauntity_of_pack          0
# Pack Price                0
# Weight (Kilograms)        0
# Freight_Cost_USD          0
# Product_Insurance_USD     0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5856 entries, 0 to 6196
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Project Code            5856 non-null   object
#  1   Country                 5856 non-null   object
#  2   Vendor INCO Term        5856 non-null   object
#  3   Shipment Mode           5856 non-null   object
#  4   Delivery Recorded Date  5856 non-null   object
#  5   Qauntity_of_pack        5856 non-null   int64
#  6   Pack Price              5856 non-null   float64
#  7   Weight (Kilograms)      5856 non-null   float64
#  8   Freight_Cost_USD        5856 non-null   float64
#  9   Product_Insurance_USD   5856 non-null   float64
# dtypes: float64(4), int64(1), object(5)
# memory usage: 503.2+ KB

# %%
data.drop(columns=['Vendor INCO Term','Delivery Recorded Date','Project Code'],inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5856 entries, 0 to 6196
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                5856 non-null   object
#  1   Shipment Mode          5856 non-null   object
#  2   Qauntity_of_pack       5856 non-null   int64
#  3   Pack Price             5856 non-null   float64
#  4   Weight (Kilograms)     5856 non-null   float64
#  5   Freight_Cost_USD       5856 non-null   float64
#  6   Product_Insurance_USD  5856 non-null   float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 366.0+ KB

# %%
data.isna().sum()
# Out:
# Country                  0
# Shipment Mode            0
# Qauntity_of_pack         0
# Pack Price               0
# Weight (Kilograms)       0
# Freight_Cost_USD         0
# Product_Insurance_USD    0
# dtype: int64

# %%
data.to_csv('data/SCMS_Datasets.csv')

# %%
df=pd.read_csv('data/SCMS_Datasets.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5856 entries, 0 to 5855
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             5856 non-null   int64
#  1   Country                5856 non-null   object
#  2   Shipment Mode          5856 non-null   object
#  3   Qauntity_of_pack       5856 non-null   int64
#  4   Pack Price             5856 non-null   float64
#  5   Weight (Kilograms)     5856 non-null   float64
#  6   Freight_Cost_USD       5856 non-null   float64
#  7   Product_Insurance_USD  5856 non-null   float64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 366.1+ KB

# %%
df.drop(columns=['Unnamed: 0'])
# Out:
#             Country Shipment Mode  Qauntity_of_pack  Pack Price  \
# 0            Rwanda           Air               100        0.01
# 1           Vietnam           Air                60        7.00
# 2           Vietnam           Air                30       23.26
# 3     Côte d'Ivoire         Truck                30       13.52
# 4           Burundi           Air                60        6.52
# ...             ...           ...               ...         ...
# 5851          Haiti           Air                30        3.33
# 5852       Ethiopia           Air                 1       24.50
# 5853        Nigeria   Air Charter                60        7.72
# 5854          Kenya           Air                 1       30.00
# 5855         Rwanda           Air                 1       24.50
#
#       Weight (Kilograms)  Freight_Cost_USD  Product_Insurance_USD
# 0                   99.0              0.75                   0.02
# ...

# %%
import seaborn as sns

# %%
##Segregate numerical and Categorical columns

numerical_columns=df.columns[df.dtypes!='object']
categorical_columns=df.columns[df.dtypes=='object']

# %%
print('numerical_columns:',numerical_columns)
print('categorical_columns',categorical_columns)
# Out:
# numerical_columns: Index(['Unnamed: 0', 'Qauntity_of_pack', 'Pack Price', 'Weight (Kilograms)',
#        'Freight_Cost_USD', 'Product_Insurance_USD'],
#       dtype='object')
# categorical_columns Index(['Country', 'Shipment Mode'], dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,10))

# %%
sns.heatmap(df.corr(numeric_only=True),annot = True)
# Out:
# <Axes: >

# %%
sns.pairplot(df)

# %%
df['Country'].unique()
# Out:
# array(['Rwanda', 'Vietnam', "Côte d'Ivoire", 'Burundi', 'Mozambique',
#        'Uganda', 'Zambia', 'Namibia', 'Congo, DRC', 'Kenya', 'Zimbabwe',
#        'Ethiopia', 'Guyana', 'Nigeria', 'Sudan', 'South Africa',
#        'Guatemala', 'Ghana', 'Haiti', 'Botswana', 'Pakistan',
#        'Dominican Republic', 'Liberia', 'Swaziland', 'Afghanistan',
#        'Cameroon', 'Malawi', 'Lesotho', 'Senegal', 'Tanzania',
#        'South Sudan', 'Libya', 'Mali', 'Angola', 'Benin', 'Guinea',
#        'Togo', 'Sierra Leone'], dtype=object)

# %%
country_map={'Rwanda':1, 'Vietnam':2, "Côte d'Ivoire":3, 'Burundi':4, 'Mozambique':5,
       'Uganda':6, 'Zambia':7, 'Namibia':8, 'Congo':9, 'DRC':10, 'Kenya':11, 'Zimbabwe':12,
       'Ethiopia':13, 'Guyana':14, 'Nigeria':15, 'Sudan':16, 'South Africa':17,
       'Guatemala':18, 'Ghana':19, 'Haiti':20, 'Botswana':21, 'Pakistan':22,
       'Dominican Republic':23, 'Liberia':24, 'Swaziland':25, 'Afghanistan':26,
       'Cameroon':27, 'Malawi':28, 'Lesotho':29, 'Senegal':30, 'Tanzania':31,
       'South Sudan':32, 'Libya':33, 'Mali':34, 'Angola':35, 'Benin':36, 'Guinea':37,
       'Togo':38, 'Sierra Leone':39}

# %%
df['Shipment Mode'].unique()
# Out:
# array(['Air', 'Truck', 'Air Charter', 'Ocean'], dtype=object)

# %%
Shipment_mode_map={'Air':1, 'Truck':2, 'Air Charter':3, 'Ocean':4}

# %%
df['Country'].map(country_map)
# Out:
# 0        1.0
# 1        2.0
# 2        2.0
# 3        3.0
# 4        4.0
#         ...
# 5851    20.0
# 5852    13.0
# 5853    15.0
# 5854    11.0
# 5855     1.0
# Name: Country, Length: 5856, dtype: float64

# %%
df['Shipment Mode'].map(Shipment_mode_map)
# Out:
# 0       1
# 1       1
# 2       1
# 3       2
# 4       1
#        ..
# 5851    1
# 5852    1
# 5853    3
# 5854    1
# 5855    1
# Name: Shipment Mode, Length: 5856, dtype: int64
